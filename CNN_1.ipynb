# %%
from google.colab import drive
drive.mount("/content/Drive")
# Out:
# Mounted at /content/Drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_profiling

# %%
path = "/content/Drive/MyDrive/Colab Notebooks/Project/nm.csv"
data = pd.read_csv(path, low_memory=False)

# %%
data.shape
# Out:
# (359764, 101)

# %%
data.head()
# Out:
#   label               Nose_x               Nose_y                Nose_z  \
# 0   001  0.49457302689552307  0.22309771180152893   -0.3240303695201874
# 1   001   0.4951612055301666  0.22475837171077728   -0.2926197648048401
# 2   001   0.4953839182853699   0.2247074544429779   -0.2693178057670593
# 3   001    0.496429443359375  0.22320719063282013  -0.24249932169914246
# 4   001    0.497236430644989  0.21879766881465912   -0.2508357763290405
#
#       Left_eye_inner_x     Left_eye_inner_y      Left_eye_inner_z  \
# 0   0.4977436065673828  0.21592164039611816  -0.31216320395469666
# 1  0.49888911843299866  0.21652071177959442   -0.2802371084690094
# 2  0.49936652183532715   0.2163585126399994   -0.2583972215652466
# 3   0.5011224746704102  0.21422404050827026  -0.23155716061592102
# 4   0.5021005272865295  0.20974834263324738  -0.23908588290214539
#
#             Left_eye_x           Left_eye_y           Left_eye_z  ...  \
# ...

# %%
count = 0
for i in range(len(data)):
    if data['label'][i] == 'label':
        data.drop(i, axis = 0, inplace = True)

# %%
data['label'][42455]
# Out:
# '009'

# %%
data.shape
# Out:
# (359698, 101)

# %%
data = data.drop('Unnamed: 100', axis = 1)

# %%
data.shape
# Out:
# (359698, 100)

# %%
data_nm = data

# %%
column = data_nm.columns
column
# Out:
# Index(['label', 'Nose_x', 'Nose_y', 'Nose_z', 'Left_eye_inner_x',
#        'Left_eye_inner_y', 'Left_eye_inner_z', 'Left_eye_x', 'Left_eye_y',
#        'Left_eye_z', 'Left_eye_outer_x', 'Left_eye_outer_y',
#        'Left_eye_outer_z', 'Right_eye_inner_x', 'Right_eye_inner_y',
#        'Right_eye_inner_z', 'Right_eye_x', 'Right_eye_y', 'Right_eye_z',
#        'Right_eye_outer_x', 'Right_eye_outer_y', 'Right_eye_outer_z',
#        'Left_ear_x', 'Left_ear_y', 'Left_ear_z', 'Right_ear_x', 'Right_ear_y',
#        'Right_ear_z', 'Mouth_left_x', 'Mouth_left_y', 'Mouth_left_z',
#        'Mouth_right_x', 'Mouth_right_y', 'Mouth_right_z', 'Left_shoulder_x',
#        'Left_shoulder_y', 'Left_shoulder_z', 'Right_shoulder_x',
#        'Right_shoulder_y', 'Right_shoulder_z', 'Left_elbow_x', 'Left_elbow_y',
#        'Left_elbow_z', 'Right_elbow_x', 'Right_elbow_y', 'Right_elbow_z',
#        'Left_wrist_x', 'Left_wrist_y', 'Left_wrist_z', 'Right_wrist_x',
# ...

# %%
for i in column[1:]:
#     df['column'] = pd.to_numeric(df['column'],errors = 'coerce')
    data_nm[i] =  pd.to_numeric( data_nm[i], errors = 'coerce')

# %%
data_nm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359698 entries, 0 to 359763
# Data columns (total 100 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   label               359698 non-null  object
#  1   Nose_x              359698 non-null  float64
#  2   Nose_y              359698 non-null  float64
#  3   Nose_z              359698 non-null  float64
#  4   Left_eye_inner_x    359698 non-null  float64
#  5   Left_eye_inner_y    359698 non-null  float64
#  6   Left_eye_inner_z    359698 non-null  float64
#  7   Left_eye_x          359698 non-null  float64
#  8   Left_eye_y          359698 non-null  float64
#  9   Left_eye_z          359698 non-null  float64
#  10  Left_eye_outer_x    359698 non-null  float64
#  11  Left_eye_outer_y    359698 non-null  float64
#  12  Left_eye_outer_z    359698 non-null  float64
#  13  Right_eye_inner_x   359698 non-null  float64
#  14  Right_eye_inner_y   359698 non-null  float64
# ...

# %%
X_train = data_nm.drop('label', axis=1)
X_train.shape
# Out:
# (359698, 99)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359698 entries, 0 to 359763
# Data columns (total 99 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Nose_x              359698 non-null  float64
#  1   Nose_y              359698 non-null  float64
#  2   Nose_z              359698 non-null  float64
#  3   Left_eye_inner_x    359698 non-null  float64
#  4   Left_eye_inner_y    359698 non-null  float64
#  5   Left_eye_inner_z    359698 non-null  float64
#  6   Left_eye_x          359698 non-null  float64
#  7   Left_eye_y          359698 non-null  float64
#  8   Left_eye_z          359698 non-null  float64
#  9   Left_eye_outer_x    359698 non-null  float64
#  10  Left_eye_outer_y    359698 non-null  float64
#  11  Left_eye_outer_z    359698 non-null  float64
#  12  Right_eye_inner_x   359698 non-null  float64
#  13  Right_eye_inner_y   359698 non-null  float64
#  14  Right_eye_inner_z   359698 non-null  float64
# ...

# %%
X_train.head()
# Out:
#      Nose_x    Nose_y    Nose_z  Left_eye_inner_x  Left_eye_inner_y  \
# 0  0.494573  0.223098 -0.324030          0.497744          0.215922
# 1  0.495161  0.224758 -0.292620          0.498889          0.216521
# 2  0.495384  0.224707 -0.269318          0.499367          0.216359
# 3  0.496429  0.223207 -0.242499          0.501122          0.214224
# 4  0.497236  0.218798 -0.250836          0.502101          0.209748
#
#    Left_eye_inner_z  Left_eye_x  Left_eye_y  Left_eye_z  Left_eye_outer_x  \
# 0         -0.312163    0.499854    0.215958   -0.312215          0.501896
# 1         -0.280237    0.501336    0.216520   -0.280256          0.503606
# 2         -0.258397    0.501857    0.216419   -0.258412          0.504175
# 3         -0.231557    0.503852    0.214484   -0.231567          0.506044
# 4         -0.239086    0.504814    0.209998   -0.239108          0.507001
#
#    ...  Left_heel_z  Right_heel_x  Right_heel_y  Right_heel_z  \
# ...

# %%
# data['label'][42306] = data['label'][42305]
# y =  data_nm.label.astype(str)
# y

# y_train = data_nm['label']

# data_nm.dtypes
# Out:
# C:\Users\mritu\AppData\Local\Temp/ipykernel_8696/587378573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label'][42306] = data['label'][42305]

# %%
data['label'].dtypes
# Out:
# dtype('O')

# %%
y =  data['label']
y = pd.to_numeric(y)

# %%
y.dtypes
# Out:
# dtype('int64')

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359698 entries, 0 to 359763
# Data columns (total 99 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Nose_x              359698 non-null  float64
#  1   Nose_y              359698 non-null  float64
#  2   Nose_z              359698 non-null  float64
#  3   Left_eye_inner_x    359698 non-null  float64
#  4   Left_eye_inner_y    359698 non-null  float64
#  5   Left_eye_inner_z    359698 non-null  float64
#  6   Left_eye_x          359698 non-null  float64
#  7   Left_eye_y          359698 non-null  float64
#  8   Left_eye_z          359698 non-null  float64
#  9   Left_eye_outer_x    359698 non-null  float64
#  10  Left_eye_outer_y    359698 non-null  float64
#  11  Left_eye_outer_z    359698 non-null  float64
#  12  Right_eye_inner_x   359698 non-null  float64
#  13  Right_eye_inner_y   359698 non-null  float64
#  14  Right_eye_inner_z   359698 non-null  float64
# ...

# %%
y_train = pd.DataFrame(y,columns=['label'])
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359698 entries, 0 to 359763
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   label   359698 non-null  int64
# dtypes: int64(1)
# memory usage: 13.6 MB

# %%
y_train
# Out:
#         label
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 359759     70
# 359760     70
# 359761     70
# 359762     70
# 359763     70
#
# [359698 rows x 1 columns]

# %%
# !pip install pandas-profiling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
updated_nm = pd.concat([X_train, y_train],axis=1, join='inner')
updated_nm
# Out:
#           Nose_x    Nose_y    Nose_z  Left_eye_inner_x  Left_eye_inner_y  \
# 0       0.494573  0.223098 -0.324030          0.497744          0.215922
# 1       0.495161  0.224758 -0.292620          0.498889          0.216521
# 2       0.495384  0.224707 -0.269318          0.499367          0.216359
# 3       0.496429  0.223207 -0.242499          0.501122          0.214224
# 4       0.497236  0.218798 -0.250836          0.502101          0.209748
# ...          ...       ...       ...               ...               ...
# 359759  0.501547  0.229633  0.101145          0.499510          0.223180
# 359760  0.501751  0.227078  0.123964          0.499760          0.221167
# 359761  0.501804  0.227192  0.125813          0.499872          0.221206
# 359762  0.502510  0.227479  0.122203          0.500876          0.221534
# 359763  0.503887  0.230906 -0.005688          0.503390          0.224599
#
#         Left_eye_inner_z  Left_eye_x  Left_eye_y  Left_eye_z  \
# ...

# %%
updated_nm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359698 entries, 0 to 359763
# Data columns (total 100 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Nose_x              359698 non-null  float64
#  1   Nose_y              359698 non-null  float64
#  2   Nose_z              359698 non-null  float64
#  3   Left_eye_inner_x    359698 non-null  float64
#  4   Left_eye_inner_y    359698 non-null  float64
#  5   Left_eye_inner_z    359698 non-null  float64
#  6   Left_eye_x          359698 non-null  float64
#  7   Left_eye_y          359698 non-null  float64
#  8   Left_eye_z          359698 non-null  float64
#  9   Left_eye_outer_x    359698 non-null  float64
#  10  Left_eye_outer_y    359698 non-null  float64
#  11  Left_eye_outer_z    359698 non-null  float64
#  12  Right_eye_inner_x   359698 non-null  float64
#  13  Right_eye_inner_y   359698 non-null  float64
#  14  Right_eye_inner_z   359698 non-null  float64
# ...

# %%
updated_nm['Nose_x'][4]
# Out:
# 0.497236430644989

# %%
# updated_nm.profile_report()

# %% [markdown]
# ### CNN

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(50, input_shape=(99,), activation = 'relu'),
    keras.layers.Dense(71,  activation = 'sigmoid')
])

model.compile(optimizer = 'adam', 
              loss= 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 11241/11241 [==============================] - 26s 2ms/step - loss: 3.8502 - accuracy: 0.0666
# Epoch 2/50
# 11241/11241 [==============================] - 23s 2ms/step - loss: 3.5518 - accuracy: 0.1023
# Epoch 3/50
# 11241/11241 [==============================] - 24s 2ms/step - loss: 3.4554 - accuracy: 0.1176
# Epoch 4/50
# 11241/11241 [==============================] - 25s 2ms/step - loss: 3.3884 - accuracy: 0.1297
# Epoch 5/50
# 11241/11241 [==============================] - 23s 2ms/step - loss: 3.3302 - accuracy: 0.1410
# Epoch 6/50
# 11241/11241 [==============================] - 24s 2ms/step - loss: 3.2787 - accuracy: 0.1502
# Epoch 7/50
# 11241/11241 [==============================] - 25s 2ms/step - loss: 3.2328 - accuracy: 0.1589
# Epoch 8/50
# 11241/11241 [==============================] - 23s 2ms/step - loss: 3.1920 - accuracy: 0.1675
# Epoch 9/50
# 11241/11241 [==============================] - 24s 2ms/step - loss: 3.1562 - accuracy: 0.1730
# Epoch 10/50
# ...

# %% [markdown]
# ### Testing

# %%
path = "/content/Drive/MyDrive/Colab Notebooks/Project/bg.csv"
data_bg = pd.read_csv(path, low_memory=False, on_bad_lines='skip')

# %%
data.shape
# Out:
# (359698, 100)

# %%
data.head()
# Out:
#   label    Nose_x    Nose_y    Nose_z  Left_eye_inner_x  Left_eye_inner_y  \
# 0   001  0.494573  0.223098 -0.324030          0.497744          0.215922
# 1   001  0.495161  0.224758 -0.292620          0.498889          0.216521
# 2   001  0.495384  0.224707 -0.269318          0.499367          0.216359
# 3   001  0.496429  0.223207 -0.242499          0.501122          0.214224
# 4   001  0.497236  0.218798 -0.250836          0.502101          0.209748
#
#    Left_eye_inner_z  Left_eye_x  Left_eye_y  Left_eye_z  ...  Left_heel_z  \
# 0         -0.312163    0.499854    0.215958   -0.312215  ...     0.202568
# 1         -0.280237    0.501336    0.216520   -0.280256  ...     0.155706
# 2         -0.258397    0.501857    0.216419   -0.258412  ...     0.137647
# 3         -0.231557    0.503852    0.214484   -0.231567  ...     0.073111
# 4         -0.239086    0.504814    0.209998   -0.239108  ...     0.130933
#
#    Right_heel_x  Right_heel_y  Right_heel_z  Left_foot_index_x  \
# ...

# %%
count = 0
for i in range(len(data_bg)):
    if data_bg['label'][i] == 'label':
        data_bg.drop(i, axis = 0, inplace = True)
        count+=1
count

# %%
data_bg['label'][15621]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 15621
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data_bg = data_bg.drop('Unnamed: 100', axis = 1)

# %%
column = data_bg.columns
column
# Out:
# Index(['label', 'Nose_x', 'Nose_y', 'Nose_z', 'Left_eye_inner_x',
#        'Left_eye_inner_y', 'Left_eye_inner_z', 'Left_eye_x', 'Left_eye_y',
#        'Left_eye_z', 'Left_eye_outer_x', 'Left_eye_outer_y',
#        'Left_eye_outer_z', 'Right_eye_inner_x', 'Right_eye_inner_y',
#        'Right_eye_inner_z', 'Right_eye_x', 'Right_eye_y', 'Right_eye_z',
#        'Right_eye_outer_x', 'Right_eye_outer_y', 'Right_eye_outer_z',
#        'Left_ear_x', 'Left_ear_y', 'Left_ear_z', 'Right_ear_x', 'Right_ear_y',
#        'Right_ear_z', 'Mouth_left_x', 'Mouth_left_y', 'Mouth_left_z',
#        'Mouth_right_x', 'Mouth_right_y', 'Mouth_right_z', 'Left_shoulder_x',
#        'Left_shoulder_y', 'Left_shoulder_z', 'Right_shoulder_x',
#        'Right_shoulder_y', 'Right_shoulder_z', 'Left_elbow_x', 'Left_elbow_y',
#        'Left_elbow_z', 'Right_elbow_x', 'Right_elbow_y', 'Right_elbow_z',
#        'Left_wrist_x', 'Left_wrist_y', 'Left_wrist_z', 'Right_wrist_x',
# ...

# %%
for i in column[1:]:
    data_bg[i] =  pd.to_numeric( data_bg[i], errors = 'coerce')

# %%
data_bg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119510 entries, 0 to 119520
# Data columns (total 100 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   label               119510 non-null  object
#  1   Nose_x              119510 non-null  float64
#  2   Nose_y              119510 non-null  float64
#  3   Nose_z              119510 non-null  float64
#  4   Left_eye_inner_x    119510 non-null  float64
#  5   Left_eye_inner_y    119510 non-null  float64
#  6   Left_eye_inner_z    119510 non-null  float64
#  7   Left_eye_x          119510 non-null  float64
#  8   Left_eye_y          119510 non-null  float64
#  9   Left_eye_z          119510 non-null  float64
#  10  Left_eye_outer_x    119510 non-null  float64
#  11  Left_eye_outer_y    119510 non-null  float64
#  12  Left_eye_outer_z    119510 non-null  float64
#  13  Right_eye_inner_x   119510 non-null  float64
#  14  Right_eye_inner_y   119510 non-null  float64
# ...

# %%
X_test_bg = data_bg.drop('label', axis=1)
X_test_bg.shape
# Out:
# (119510, 99)

# %%
X_test_bg.head()
# Out:
#      Nose_x    Nose_y    Nose_z  Left_eye_inner_x  Left_eye_inner_y  \
# 0  0.473632  0.232449 -0.268988          0.476908          0.223113
# 1  0.473632  0.229857 -0.278472          0.477046          0.220798
# 2  0.475242  0.229045 -0.301750          0.479076          0.219955
# 3  0.476663  0.228689 -0.291974          0.480628          0.219341
# 4  0.477430  0.224488 -0.305598          0.481629          0.215511
#
#    Left_eye_inner_z  Left_eye_x  Left_eye_y  Left_eye_z  Left_eye_outer_x  \
# 0         -0.258241    0.479228    0.222534   -0.258276          0.481544
# 1         -0.267030    0.479490    0.220538   -0.267047          0.481927
# 2         -0.289518    0.481711    0.219800   -0.289551          0.484306
# 3         -0.280518    0.483247    0.219185   -0.280557          0.485791
# 4         -0.294445    0.484362    0.215463   -0.294485          0.486937
#
#    ...  Left_heel_z  Right_heel_x  Right_heel_y  Right_heel_z  \
# ...

# %%
data_bg['label'].dtypes
# Out:
# dtype('O')

# %%
y_test_bg =  data_bg['label']
y_test_bg = pd.to_numeric(y_test_bg)

# %%
y_test_bg = pd.DataFrame(y_test_bg,columns=['label'])
y_test_bg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119510 entries, 0 to 119520
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   label   119510 non-null  int64
# dtypes: int64(1)
# memory usage: 5.9 MB

# %%
y_test_bg.tail()
# Out:
#         label
# 119516     70
# 119517     70
# 119518     70
# 119519     70
# 119520     70

# %% [markdown]
# ### predicion

# %%
model.evaluate(X_test_bg, y_test_bg)
# Out:
# 3735/3735 [==============================] - 6s 2ms/step - loss: 3.1126 - accuracy: 0.1960
# [3.1125833988189697, 0.19595849514007568]

# %%
y_pred = model.predict(X_test_bg)
# Out:
# 3735/3735 [==============================] - 7s 2ms/step

# %%
output_labels = [np.argmax(i) for i in y_pred]
output_labels

# %%
import sklearn
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test_bg, output_labels, normalize=True, sample_weight=None)
accuracy
# Out:
# 0.19596686469751484

# %%
confusion_matrix = tf.math.confusion_matrix(labels = y_test_bg, predictions = output_labels )
confusion_matrix
# Out:
# <tf.Tensor: shape=(71, 71), dtype=int32, numpy=
# array([[  0,   0,   0, ...,   0,   0,   0],
#        [  0,  46,  59, ...,  33,   3,  40],
#        [  0,  14, 186, ...,  25,   0,  10],
#        ...,
#        [  0,   8,  30, ...,  60,   8,  42],
#        [  0,  10,  32, ...,  27,   4,   6],
#        [  0,   3,   6, ...,   5,   0, 141]], dtype=int32)>

# %%
import seaborn as sbn

# %%
plt.figure(figsize = (50,35))
sbn.heatmap(confusion_matrix, annot = True, fmt = 'd')
plt.xlabel("prediction")
plt.ylabel("True")
# Out:
# Text(429.0, 0.5, 'True')
